# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# Objective:
# - Combine and integrate data from multiple sources using merging, concatenating, or joining techniques to generate more comprehensive and meaningful datasets for analysis.
# - Modify the structure of data by pivoting, stacking/unstacking, or melting dataframes, enabling them to efficiently explore and analyze complex datasets.

# %% [markdown]
# # Challenge 1: Combining Data

# %% [markdown]
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the following links:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv

# %% [markdown]
# Perform data cleaning and formatting using the main cleaning and formatting function created in the previous lab to clean and format the data.

# %% [markdown]
# Combine the data from the three dataframes into a single dataframe, named "customer_data", using appropriate merging, concatenating, and joining techniques.
#
# Verify that the customer_data dataframe contains all the rows and columns from the three original dataframes.

# %% [markdown]
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd
import numpy as np
import functions as funcs

df1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')# load file 1
df2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')# load file 2
df3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')# load file 3

# clean file 1 data
df1_cleaned = funcs.clean_and_format_data(df1,
                                        {'customer':'customer_id', 'st':'state'},
                                        {'customer_lifetime_value':[['%','']],
                                         'state':[['AZ','Arizona'],['WA','Washington'],['Cali','California']],
                                         'education': [['Bachelors','Bachelor']]},
                                        {'number_of_open_complaints': 'int',
                                         'customer_lifetime_value': 'float'})
# clean file 2 data
df2_cleaned = funcs.clean_and_format_data(df2,
                                        {'customer':'customer_id', 'st':'state'},
                                        {'customer_lifetime_value':[['%','']],
                                         'state':[['AZ','Arizona'],['WA','Washington'],['Cali','California']],
                                         'education': [['Bachelors','Bachelor']]},
                                        {'number_of_open_complaints': 'int',
                                         'customer_lifetime_value': 'float'})
# clean file 3 data
df3_cleaned = funcs.clean_and_format_data(df3,
                                        {'customer':'customer_id', 'st':'state'},
                                        {},
                                        {'number_of_open_complaints': 'int',
                                         'customer_lifetime_value': 'float'})

# merge data
data = pd.concat([df1_cleaned, df2_cleaned, df3_cleaned], axis=0)

data # show data
# Out:
#      customer_id             state gender             education  \
# 1        QZ44356           Arizona      F              Bachelor
# 2        AI49188            Nevada      F              Bachelor
# 3        WW63253  Californiafornia      M              Bachelor
# 4        GA49547        Washington      M  High School or Below
# 5        OC83172            Oregon      F              Bachelor
# ...          ...               ...    ...                   ...
# 7065     LA72316        California      M              Bachelor
# 7066     PK87824        California      F               College
# 7067     TD14365        California      M              Bachelor
# 7068     UP19263        California      M               College
# 7069     Y167826        California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# 3                7.645862e+05      0.0                 106.0
# 4                5.363077e+05  36357.0                  68.0
# 5                8.256298e+05  62902.0                  69.0
# ...                       ...      ...                   ...
# 7065             2.340599e+04  71941.0                  73.0
# 7066             3.096511e+03  21604.0                  79.0
# 7067             8.163890e+03      0.0                  85.0
# 7068             7.524442e+03  21941.0                  96.0
# 7069             2.611837e+03      0.0                  77.0
#
#       number_of_open_complaints     policy_type  vehicle_class  \
# 1                             0   Personal Auto  Four-Door Car
# 2                             0   Personal Auto   Two-Door Car
# 3                             0  Corporate Auto            SUV
# 4                             0   Personal Auto  Four-Door Car
# 5                             0   Personal Auto   Two-Door Car
# ...                         ...             ...            ...
# 7065                          0   Personal Auto  Four-Door Car
# 7066                          0  Corporate Auto  Four-Door Car
# 7067                          3  Corporate Auto  Four-Door Car
# 7068                          0   Personal Auto  Four-Door Car
# 7069                          0  Corporate Auto   Two-Door Car
#
#       total_claim_amount
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# 5             159.383042
# ...                  ...
# 7065          198.234764
# 7066          379.200000
# 7067          790.784983
# 7068          691.200000
# 7069          369.600000
#
# [9010 rows x 11 columns]

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %% [markdown]
# ## Exercise 1: Clean and Format the Data

# %% [markdown]
# While the dataset has been partially cleaned and formatted, we still need to perform several data cleaning tasks. Specifically, we need to standardize the column names, clean null values, convert the effective_to_date column to datetime, and extract the months from the dataset and store them in a separate column.
#
# To accomplish these tasks, we will use the functions created in the previous step to standardize the column names and deal with null values, and then we will apply additional functions to convert the effective_to_date column to datetime and extract the months.
#
# Save the clean dataset into a csv file.

# %%
# load marketing customer analysis data
mca_data = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis.csv')

mca_data_clean = funcs.clean_and_format_data(mca_data,
                                        {'customer':'customer_id', 'st':'state'},
                                        {},
                                        {'number_of_open_complaints': 'int',
                                         'customer_lifetime_value': 'float'}) # clean the data

mca_data_clean
# Out:
#        unnamed:_0 customer_id       state  customer_lifetime_value response  \
# 2               2     LZ68649  Washington             14947.917300       No
# 3               3     XL78013      Oregon             22332.439460      Yes
# 10             10     HG93801     Arizona              5154.764074       No
# 13             13     KR82385  California              5454.587929       No
# 16             16     FH51383  California              5326.677654       No
# ...           ...         ...         ...                      ...      ...
# 10902       10902     PP30874  California              3579.023825       No
# 10903       10903     SU71163     Arizona              2771.663013       No
# 10904       10904     QI63521      Nevada             19228.463620       No
# 10906       10906     KX53892      Oregon              5259.444853       No
# 10908       10908     WA60547  California             11971.977650       No
#
#        coverage             education effective_to_date employmentstatus  \
# 2         Basic              Bachelor           2/10/11         Employed
# 3      Extended               College           1/11/11         Employed
# 10     Extended  High School or Below            1/2/11         Employed
# 13        Basic                Master           1/26/11         Employed
# 16        Basic  High School or Below            2/7/11         Employed
# ...         ...                   ...               ...              ...
# 10902  Extended  High School or Below           1/24/11         Employed
# 10903     Basic               College            1/7/11         Employed
# 10904     Basic  High School or Below           2/24/11       Unemployed
# 10906     Basic               College            1/6/11         Employed
# 10908   Premium               College           2/13/11         Employed
#
#       gender  ...  number_of_open_complaints number_of_policies  \
# 2          M  ...                          0                  2
# 3          M  ...                          0                  2
# 10         M  ...                          0                  1
# 13         M  ...                          0                  4
# 16         F  ...                          0                  6
# ...      ...  ...                        ...                ...
# 10902      F  ...                          2                  1
# 10903      M  ...                          4                  1
# 10904      M  ...                          0                  2
# 10906      F  ...                          0                  6
# 10908      F  ...                          4                  6
#
#           policy_type        policy  renew_offer_type  sales_channel  \
# 2       Personal Auto   Personal L3            Offer3    Call Center
# 3      Corporate Auto  Corporate L3            Offer2         Branch
# 10     Corporate Auto  Corporate L3            Offer2         Branch
# 13      Personal Auto   Personal L3            Offer4    Call Center
# 16      Personal Auto   Personal L3            Offer4    Call Center
# ...               ...           ...               ...            ...
# 10902   Personal Auto   Personal L2            Offer2          Agent
# 10903   Personal Auto   Personal L2            Offer2         Branch
# 10904   Personal Auto   Personal L2            Offer1         Branch
# 10906   Personal Auto   Personal L3            Offer2         Branch
# 10908   Personal Auto   Personal L1            Offer1         Branch
#
#        total_claim_amount  vehicle_class vehicle_size vehicle_type
# 2              480.000000            SUV      Medsize            A
# 3              484.013411  Four-Door Car      Medsize            A
# 10             442.521087            SUV        Large            A
# 13             331.200000   Two-Door Car      Medsize            A
# 16             300.528579   Two-Door Car        Large            A
# ...                   ...            ...          ...          ...
# 10902          655.200000  Four-Door Car      Medsize            A
# 10903          355.200000   Two-Door Car      Medsize            A
# 10904          897.600000     Luxury SUV      Medsize            A
# 10906          273.018929  Four-Door Car      Medsize            A
# 10908          618.288849            SUV      Medsize            A
#
# [4543 rows x 26 columns]

# %%
def convert_column_to_datetime(df: pd.DataFrame, column_name: str) -> pd.DataFrame:
    '''
    This function turns a string column into date time format
    
    Input:
    df: input DataFrame
    
    Output
    df: outout DataFrame with converted column
    '''
    
    df1 = df.copy()
    
    df1[column_name] = pd.to_datetime(df[column_name], errors='coerce')
    
    return df1

# %%
mca_data_clean = convert_column_to_datetime(mca_data_clean,'effective_to_date')# convert effective_to_date to datetime type

mca_data_clean['effective_to_date_month'] = mca_data_clean['effective_to_date'].dt.month# add a new column with the month

mca_data_clean.to_csv('mca_data_clean.csv',index = False, sep=";")# save data to csv file

mca_data_clean.head(50)# show clean data
# Out:
#      unnamed:_0 customer_id       state  customer_lifetime_value response  \
# 2             2     LZ68649  Washington             14947.917300       No
# 3             3     XL78013      Oregon             22332.439460      Yes
# 10           10     HG93801     Arizona              5154.764074       No
# 13           13     KR82385  California              5454.587929       No
# 16           16     FH51383  California              5326.677654       No
# 17           17     TR26615      Oregon              2497.531509       No
# 18           18     ZC97968  California              2736.352663       No
# 19           19     NJ54277  California              3746.751625      Yes
# 20           20     OM80593  California              7247.313475       No
# 22           22     EQ62488      Oregon             15031.564500       No
# 24           24     YK32760      Oregon              2502.209885       No
# 25           25     AY59197      Nevada              9521.222806       No
# 26           26     XF15789     Arizona              8869.619888       No
# 28           28     CI99444      Nevada              2926.886293       No
# 30           30     GX19342  California              8491.465719       No
# 32           32     OJ63606     Arizona              5776.338737       No
# 39           39     XD72019      Oregon              8470.043225       No
# 40           40     RR93140  California              2880.348532       No
# 42           42     PV62583      Nevada              9799.175061       No
# 43           43     BL12371     Arizona              5790.565333       No
# 45           45     RI22468     Arizona              5745.943340       No
# 48           48     UY32623  California              3593.126450       No
# 102  ...                   1   Personal Auto   Personal L2            Offer2
# 103  ...                   2  Corporate Auto  Corporate L3            Offer3
# 105  ...                   2   Personal Auto   Personal L2            Offer3
# 110  ...                   5  Corporate Auto  Corporate L2            Offer1
# 113  ...                   3  Corporate Auto  Corporate L2            Offer1
# 114  ...                   7   Personal Auto   Personal L1            Offer3
# 115  ...                   1  Corporate Auto  Corporate L3            Offer1
# 117  ...                   1   Personal Auto   Personal L2            Offer1
# 118  ...                   2   Personal Auto   Personal L3            Offer3
#
#      sales_channel  total_claim_amount  vehicle_class  vehicle_size  \
# 2      Call Center          480.000000            SUV       Medsize
# 3           Branch          484.013411  Four-Door Car       Medsize
# 10          Branch          442.521087            SUV         Large
# 13     Call Center          331.200000   Two-Door Car       Medsize
# 16     Call Center          300.528579   Two-Door Car         Large
# 17          Branch          272.381465   Two-Door Car       Medsize
# 18           Agent          350.400000   Two-Door Car       Medsize
# 19     Call Center           19.575683   Two-Door Car         Large
# 20     Call Center          499.200000            SUV       Medsize
# 22     Call Center          907.200000     Luxury Car         Large
# 24           Agent          355.200000  Four-Door Car       Medsize
# 25           Agent          123.154160            SUV         Small
# 26          Branch          228.185834            SUV         Large
# 28     Call Center          234.774747  Four-Door Car       Medsize
# 30          Branch         1193.115879  Four-Door Car         Large
# 32     Call Center          871.457982            SUV         Small
# 39             Web          479.312226  Four-Door Car         Large
# 40          Branch          190.642833  Four-Door Car       Medsize
# 42             Web          604.800000            SUV       Medsize
# 43           Agent           28.925840  Four-Door Car         Large
# 45             Web          269.905129  Four-Door Car       Medsize
# 48          Branch          460.800000  Four-Door Car         Large
# 49     Call Center          272.788141            SUV       Medsize
# 50             Web          302.400000  Four-Door Car       Medsize
# 55           Agent         2294.631639     Luxury Car       Medsize
# 57          Branch          756.000000  Four-Door Car         Small
# 60          Branch          396.035334  Four-Door Car         Small
# 61     Call Center          302.400000   Two-Door Car       Medsize
# 64           Agent           41.464402  Four-Door Car       Medsize
# 66           Agent          302.400000  Four-Door Car       Medsize
# 68          Branch          483.257210  Four-Door Car       Medsize
# 69     Call Center          374.400000  Four-Door Car       Medsize
# 71           Agent          369.600000  Four-Door Car       Medsize
# 78             Web          612.000000  Four-Door Car         Small
# 80          Branch           33.718553  Four-Door Car       Medsize
# 82          Branch          525.600000  Four-Door Car         Small
# 85     Call Center          734.400000            SUV         Small
# 90           Agent          532.800000            SUV         Small
# 95     Call Center          733.737214     Sports Car       Medsize
# 98     Call Center          370.018108  Four-Door Car       Medsize
# 101          Agent          561.600000            SUV       Medsize
# 102          Agent          114.273025   Two-Door Car       Medsize
# 103         Branch          408.000000   Two-Door Car       Medsize
# 105         Branch          388.800000  Four-Door Car       Medsize
# 110          Agent          497.719213            SUV       Medsize
# 113          Agent          312.000000  Four-Door Car         Small
# 114            Web         1214.400000     Luxury Car       Medsize
# 115          Agent          534.653787     Luxury Car       Medsize
# 117            Web          236.739322            SUV       Medsize
# 118    Call Center          566.673518  Four-Door Car       Medsize
#
#     vehicle_type effective_to_date_month
# 2              A                       2
# 3              A                       1
# 10             A                       1
# 13             A                       1
# 16             A                       2
# 17             A                       1
# 18             A                       2
# 19             A                       2
# 20             A                       2
# 22             A                       1
# 24             A                       2
# 25             A                       1
# 26             A                       2
# 28             A                       2
# 30             A                       1
# 32             A                       1
# 39             A                       2
# 40             A                       1
# 42             A                       1
# 43             A                       2
# 45             A                       1
# 48             A                       2
# 49             A                       2
# 50             A                       2
# 55             A                       2
# 57             A                       1
# 60             A                       1
# 61             A                       2
# 64             A                       2
# 66             A                       1
# 68             A                       1
# 69             A                       1
# 71             A                       1
# 78             A                       2
# 80             A                       2
# 82             A                       2
# 85             A                       1
# 90             A                       2
# 95             A                       2
# 98             A                       1
# 101            A                       2
# 102            A                       1
# 103            A                       1
# 105            A                       2
# 110            A                       2
# 113            A                       1
# 114            A                       1
# 115            A                       1
# 117            A                       2
# 118            A                       1
#
# [50 rows x 27 columns]

# %%
# !ls
# Out:
# README.md
# __pycache__
# functions.py
# lab-dw-data-structuring-and-combining.ipynb
# mca_data_clean.csv

# %% [markdown]
# ## Exercise 2: Structuring Data

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# 3. You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# 1.

df1 = mca_data_clean.pivot_table(values='monthly_premium_auto', index='sales_channel', aggfunc='sum').round(2)

display(df1)
print("'Agent' is the sales channel with the highest revenue.")

# 2.

df2 = mca_data_clean.pivot_table(values='customer_lifetime_value',index=['education','gender'], aggfunc='mean').round(2)

display(df2)
print("There is no apparent strong dependency between education/gender and customer lifetime value.")

# 3.

df3 = mca_data_clean.pivot_table(values='number_of_policies', index=['policy_type'], columns=['effective_to_date_month'], aggfunc='sum').round(2)

#display(df3)

df3_melt = pd.melt(df3.reset_index(), id_vars='policy_type', var_name='effective_to_date_month' , value_name='number_of_policies')

display(df3_melt)
# Out:
#                monthly_premium_auto
# sales_channel
# Agent                        164054
# Branch                       117853
# Call Center                   82706
# Web                           61399
# 'Agent' is the sales channel with the highest revenue.
#                              customer_lifetime_value
# education            gender
# Bachelor             F                       8039.29
#                      M                       8125.26
# College              F                       7798.08
#                      M                       7984.30
# Doctor               F                       8475.30
#                      M                       7659.74
# High School or Below F                       8475.52
#                      M                       7730.15
# Master               F                       8243.13
#                      M                       8013.87
# There is no apparent strong dependency between education/gender and customer lifetime value.
#       policy_type effective_to_date_month  number_of_policies
# 0  Corporate Auto                       1                1435
# 1   Personal Auto                       1                5326
# 2    Special Auto                       1                 282
# 3  Corporate Auto                       2                1430
# 4   Personal Auto                       2                4769
# 5    Special Auto                       2                 297
